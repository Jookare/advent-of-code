# %% [markdown]
# ### Test inputs

# %%
inputs = [
    [162,817,812],
    [57,618,57],
    [906,360,560],
    [592,479,940],
    [352,342,300],
    [466,668,158],
    [542,29,236],
    [431,825,988],
    [739,650,466],
    [52,470,668],
    [216,146,977],
    [819,987,18],
    [117,168,530],
    [805,96,715],
    [346,949,466],
    [970,615,88],
    [941,993,340],
    [862,61,35],
    [984,92,344],
    [425,690,689],
]

# %%
distances = []
dists2 = {}
for i, val1 in enumerate(inputs):
    dists = []
    # print(val1)
    for j, val2 in enumerate(inputs):
        if  j != i:
            dists += [((val1[0] - val2[0])**2 + (val1[1] - val2[1])**2 + (val1[2] - val2[2])**2)**0.5]
        else:
            dists += [0]
    dists2[i] = dists
    distances += [dists]

# %%
# for row in distances:
    # print(list(map(round, row, [1]*len(row))))

# %%
min_dist = []
minim = 10000
for key in dists2.keys():
    row = dists2[key]
    print(row)
    for val in row[key+1:]:
        if val < minim:
            minim = val
    print(minim)
    minim = 10000
# Out:
# [0, 787.814064357828, 908.7843528582565, 561.7187908553532, 723.7879523727927, 736.432617419951, 1047.4349621814235, 321.560258738545, 693.2055972076394, 391.46519640959144, 693.0959529531247, 1044.5022738127477, 709.0486584149215, 970.9268767523124, 413.5166260260886, 1103.5596948058587, 927.6858304404568, 1290.4514713851117, 1191.7772442868675, 316.90219311326956]
# 316.90219311326956
# [787.814064357828, 0, 1019.9872548223335, 1041.746130302388, 471.4339826529267, 424.24285497813634, 783.7008357785514, 1024.444239575781, 795.8825290204579, 628.6891123599962, 1046.1668127024486, 847.5411494434945, 655.6134531871658, 1124.700849114999, 600.3024237832128, 913.5310613219455, 1001.0844120252797, 979.1618865131546, 1103.7998006885125, 734.8686957545546]
# 424.24285497813634
# ...
